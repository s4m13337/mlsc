# %% [markdown]
# # Environment Checks
#
# This notebook for quickly checking if the standard packages required for machine learning, numeric and scientific computations are installed.

# %% [markdown]
# **Check if the python being used belongs to a virtual or global environment**

# %%
# !echo "Python is being sourced from $(which python)"
# !echo "Python version is $(python --version)"
# Out:
# Python is being sourced from /Users/s4m13337/Developer/mlsc/bin/python
# Python version is Python 3.10.19

# %% [markdown]
# ## Numpy

# %%
import numpy as np
x = np.arange(0, 10, 0.01)
y = np.sin(x)

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot(x, y)

# %% [markdown]
# ## PyTorch

# %%
import torch

# %%
if torch.backends.mps.is_available():
    print("MPS device found.")
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# MPS device found.
# tensor([1.], device='mps:0')
